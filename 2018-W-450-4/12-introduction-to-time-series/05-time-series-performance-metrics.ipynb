# %% [markdown]
# # Introduction to Time Series
#
# ## Forecasting Performance Metrics

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels as sm

# %matplotlib inline

bike_sharing_df = pd.read_csv('bike_sharing_day.csv', index_col=0)
bike_sharing_df.dteday = pd.to_datetime(bike_sharing_df.dteday)

bike_sharing_df.set_index('dteday', inplace=True)
bike_sharing_df.head()
# Out:
#             season  yr  mnth  holiday  weekday  workingday  weathersit  \
# dteday
# 2011-01-01       1   0     1        0        6           0           2
# 2011-01-02       1   0     1        0        0           0           2
# 2011-01-03       1   0     1        0        1           1           1
# 2011-01-04       1   0     1        0        2           1           1
# 2011-01-05       1   0     1        0        3           1           1
#
#                 temp     atemp       hum  windspeed  casual  registered   cnt
# dteday
# 2011-01-01  0.344167  0.363625  0.805833   0.160446     331         654   985
# 2011-01-02  0.363478  0.353739  0.696087   0.248539     131         670   801
# 2011-01-03  0.196364  0.189405  0.437273   0.248309     120        1229  1349
# 2011-01-04  0.200000  0.212122  0.590435   0.160296     108        1454  1562
# 2011-01-05  0.226957  0.229270  0.436957   0.186900      82        1518  1600

# %%
def time_series_train_test_split(dataframe, target, pct=30):
    n = dataframe.shape[0]
    dataframe = dataframe.dropna().copy()
    train_n = int(n*(100-pct)/100)
    train_feats = list(dataframe.columns)
    train_feats.remove(target)
    return (dataframe[:train_n][train_feats],
            dataframe[train_n:][train_feats],
            dataframe[:train_n][target],
            dataframe[train_n:][target])

# %%
features = bike_sharing_df.drop(['casual','registered'], axis=1)

# %%
(feature_tr_df, 
 feature_ts_df, 
 target_tr, 
 target_ts) = time_series_train_test_split(features, 'cnt')

# %%
feature_tr_df.head()
# Out:
#             season  yr  mnth  holiday  weekday  workingday  weathersit  \
# dteday
# 2011-01-01       1   0     1        0        6           0           2
# 2011-01-02       1   0     1        0        0           0           2
# 2011-01-03       1   0     1        0        1           1           1
# 2011-01-04       1   0     1        0        2           1           1
# 2011-01-05       1   0     1        0        3           1           1
#
#                 temp     atemp       hum  windspeed
# dteday
# 2011-01-01  0.344167  0.363625  0.805833   0.160446
# 2011-01-02  0.363478  0.353739  0.696087   0.248539
# 2011-01-03  0.196364  0.189405  0.437273   0.248309
# 2011-01-04  0.200000  0.212122  0.590435   0.160296
# 2011-01-05  0.226957  0.229270  0.436957   0.186900

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.svm import SVR, LinearSVR

from sklearn.metrics import mean_absolute_error, \
                            mean_squared_error, \
                            r2_score

def fit_predict_score(model):
    
    scores_train = { 'model': model, 'dataset': 'train'}
    scores_test = { 'model': model, 'dataset': 'test'}
    model.fit(feature_tr_df, target_tr)
    
    predictions_tr = model.predict(feature_tr_df)
    predictions_ts = model.predict(feature_ts_df)
    
    scores_train['mae'] = mean_absolute_error(target_tr, predictions_tr)
    scores_test['mae'] = mean_absolute_error(target_ts, predictions_ts)
    scores_train['mse'] = mean_squared_error(target_tr, predictions_tr)
    scores_test['mse'] = mean_squared_error(target_ts, predictions_ts)
    scores_train['rmse'] = np.sqrt(mean_squared_error(target_tr, predictions_tr))
    scores_test['rmse'] = np.sqrt(mean_squared_error(target_ts, predictions_ts))
    scores_train['r2'] = r2_score(target_tr, predictions_tr)
    scores_test['r2'] = r2_score(target_ts, predictions_ts)
    
    return [scores_train, scores_test]

# %%
results = (fit_predict_score(LinearRegression()) +
           fit_predict_score(Ridge()) +
           fit_predict_score(Lasso()) +
           fit_predict_score(DecisionTreeRegressor()) +
           fit_predict_score(KNeighborsRegressor()) +
           fit_predict_score(GradientBoostingRegressor()) +
           fit_predict_score(RandomForestRegressor()) +
           fit_predict_score(SVR()) +
           fit_predict_score(LinearSVR()))

# %%
results_df = pd.DataFrame(results)
results_df['model_name'] = results_df.model.apply(lambda x: x.__class__.__name__)
results_df = results_df[['model_name', 'model', 'dataset', 'mae', 'rmse', 'mse', 'r2']]

results_df
# Out:
#                    model_name  \
# 0            LinearRegression
# 1            LinearRegression
# 2                       Ridge
# 3                       Ridge
# 4                       Lasso
# 5                       Lasso
# 6       DecisionTreeRegressor
# 7       DecisionTreeRegressor
# 8         KNeighborsRegressor
# 9         KNeighborsRegressor
# 10  GradientBoostingRegressor
# 11  GradientBoostingRegressor
# 12      RandomForestRegressor
# 13      RandomForestRegressor
# 14                        SVR
# 15                        SVR
# 16                  LinearSVR
# 17                  LinearSVR
#
#                                                 model dataset          mae  \
# 0   LinearRegression(copy_X=True, fit_intercept=Tr...   train   568.383406
# 1   LinearRegression(copy_X=True, fit_intercept=Tr...    test   832.845542
# 2   Ridge(alpha=1.0, copy_X=True, fit_intercept=Tr...   train   569.346115
# 3   Ridge(alpha=1.0, copy_X=True, fit_intercept=Tr...    test   840.392436
# 4   Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...   train   568.321956
# 5   Lasso(alpha=1.0, copy_X=True, fit_intercept=Tr...    test   836.213780
# 6   DecisionTreeRegressor(criterion='mse', max_dep...   train     0.000000
# 7   DecisionTreeRegressor(criterion='mse', max_dep...    test   965.772727
# 8   KNeighborsRegressor(algorithm='auto', leaf_siz...   train   469.331898
# 9   KNeighborsRegressor(algorithm='auto', leaf_siz...    test  2018.283636
# 10  ([DecisionTreeRegressor(criterion='friedman_ms...   train   257.632405
# 11  ([DecisionTreeRegressor(criterion='friedman_ms...    test   808.807731
# 12  (DecisionTreeRegressor(criterion='mse', max_de...   train   175.366536
# 13  (DecisionTreeRegressor(criterion='mse', max_de...    test   919.459091
# 14  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...   train  1264.057146
# 15  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3...    test  2501.449707
# 16  LinearSVR(C=1.0, dual=True, epsilon=0.0, fit_i...   train  1474.934524
# 17  LinearSVR(C=1.0, dual=True, epsilon=0.0, fit_i...    test  2346.107668
#
#            rmse           mse        r2
# 0    745.525122  5.558077e+05  0.778689
# 1   1120.883561  1.256380e+06  0.539283
# 2    749.198044  5.612977e+05  0.776503
# 3   1119.876040  1.254122e+06  0.540111
# 4    745.820017  5.562475e+05  0.778514
# 5   1120.992617  1.256624e+06  0.539194
# 6      0.000000  0.000000e+00  1.000000
# 7   1252.670083  1.569182e+06  0.424578
# 8    658.379610  4.334637e+05  0.827404
# 9   2228.518391  4.966294e+06 -0.821149
# 10   339.704593  1.153992e+05  0.954050
# 11   958.945745  9.195769e+05  0.662790
# 12   271.396987  7.365632e+04  0.970672
# 13  1112.309855  1.237233e+06  0.546304
# 14  1575.764093  2.483032e+06  0.011309
# 15  2725.205968  7.426748e+06 -1.723401
# 16  1858.501792  3.454029e+06 -0.375321
# 17  2679.016050  7.177127e+06 -1.631865

# %%
short_names = {
    'LinearRegression' : 'linrg',
    'Ridge' : 'ridge',
    'Lasso' : 'lasso',
    'DecisionTreeRegressor' : 'dtree',
    'KNeighborsRegressor' : 'knnrg',
    'GradientBoostingRegressor' : 'grbst',
    'RandomForestRegressor' : 'rndfr',
    'SVR' : 'svreg',
    'LinearSVR' : 'svlin',
}
results_df['model_short_name'] = results_df.model_name.apply(lambda x: short_names[x])

# %%
_, ax = plt.subplots(1,4,figsize=(20,6))
test_results_df = results_df[results_df.dataset == 'test']
test_results_df.set_index('model_short_name', drop=True, inplace=True)
test_results_df.mae.plot(kind='bar', rot=45, title='MAE by Model', ax=ax[0])
test_results_df.mse.plot(kind='bar', rot=45, title='MSE by Model', ax=ax[1])
test_results_df.rmse.plot(kind='bar', rot=45, title='RMSE by Model', ax=ax[2])
test_results_df.r2.plot(kind='bar', rot=45, title='RMSE by Model', ax=ax[3]) 
# always use R square, you can compare datesets, it's a ratio. The 3 negative ones are not worth exploring.
