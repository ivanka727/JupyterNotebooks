# %% [markdown]
# # Introduction to Time Series
#
# ## Feature Engineering

# %%
import pandas as pd
import statsmodels as sm

# %matplotlib inline

bike_sharing_df = pd.read_csv('bike_sharing_day.csv', index_col=0)
bike_sharing_df.dteday = pd.to_datetime(bike_sharing_df.dteday)

bike_sharing_df.set_index('dteday', inplace=True)
bike_sharing_df.head()
# Out:
#             season  yr  mnth  holiday  weekday  workingday  weathersit  \
# dteday
# 2011-01-01       1   0     1        0        6           0           2
# 2011-01-02       1   0     1        0        0           0           2
# 2011-01-03       1   0     1        0        1           1           1
# 2011-01-04       1   0     1        0        2           1           1
# 2011-01-05       1   0     1        0        3           1           1
#
#                 temp     atemp       hum  windspeed  casual  registered   cnt
# dteday
# 2011-01-01  0.344167  0.363625  0.805833   0.160446     331         654   985
# 2011-01-02  0.363478  0.353739  0.696087   0.248539     131         670   801
# 2011-01-03  0.196364  0.189405  0.437273   0.248309     120        1229  1349
# 2011-01-04  0.200000  0.212122  0.590435   0.160296     108        1454  1562
# 2011-01-05  0.226957  0.229270  0.436957   0.186900      82        1518  1600

# %% [markdown]
# ### Predict Temperature From Date Information

# %%
temp_df = bike_sharing_df[['temp']].copy()
temp_df.head()
# Out:
#                 temp
# dteday
# 2011-01-01  0.344167
# 2011-01-02  0.363478
# 2011-01-03  0.196364
# 2011-01-04  0.200000
# 2011-01-05  0.226957

# %%
temp_df.plot()

# %% [markdown]
# ### Create Lag Features

# %%
temp_df['temp_shift_1'] = temp_df.temp.shift(1)

# %%
temp_df.head()
# Out:
#                 temp  temp_shift_1
# dteday
# 2011-01-01  0.344167           NaN
# 2011-01-02  0.363478      0.344167
# 2011-01-03  0.196364      0.363478
# 2011-01-04  0.200000      0.196364
# 2011-01-05  0.226957      0.200000

# %% [markdown]
# #### Ridge Regression with Lag Feature

# %%
def time_series_train_test_split(dataframe, target, pct=30): # test is 30%
    n = dataframe.shape[0]
    dataframe = dataframe.dropna().copy()
    train_n = int(n*(100-pct)/100)
    train_feats = list(dataframe.columns)
    train_feats.remove(target)
    return (dataframe[:train_n][train_feats],
            dataframe[train_n:][train_feats],
            dataframe[:train_n][target],
            dataframe[train_n:][target])

# %%
feature_tr_df, feature_ts_df, target_tr, target_ts = time_series_train_test_split(temp_df, 'temp')

# %%
feature_tr_df.shape, feature_ts_df.shape
# Out:
# ((511, 1), (219, 1))

# %%
from sklearn.linear_model import Ridge

ridge = Ridge()

ridge.fit(feature_tr_df, target_tr)
ridge.score(feature_tr_df, target_tr), ridge.score(feature_ts_df, target_ts)
# Out:
# (0.87815958734225852, 0.91831532513301539)

# %%
predictions_df = temp_df[['temp']].copy()

# %%
predictions_df['temp_shift_1_model'] = pd.concat([pd.Series(ridge.predict(feature_tr_df), index=feature_tr_df.index),
                                                  pd.Series(ridge.predict(feature_ts_df), index=feature_ts_df.index)])

# %%
predictions_df.plot(figsize=(20,3))

# %%
predictions_df['2012-01'].plot(figsize=(20,3))

# %%
begin_testing = min(feature_ts_df.index)

# %%
begin_testing
# Out:
# Timestamp('2012-05-27 00:00:00')

# %%
predictions_df['06/2012'].plot(figsize=(20,3))

# %% [markdown]
# #### Add more Lag Features

# %%
temp_df['temp_shift_2'] = temp_df.temp.shift(2)
temp_df['temp_shift_3'] = temp_df.temp.shift(3)
temp_df['temp_shift_4'] = temp_df.temp.shift(4)
temp_df['temp_shift_5'] = temp_df.temp.shift(5)

# %%
temp_df.head(10)
# Out:
#                 temp  temp_shift_1  temp_shift_2  temp_shift_3  temp_shift_4  \
# dteday
# 2011-01-01  0.344167           NaN           NaN           NaN           NaN
# 2011-01-02  0.363478      0.344167           NaN           NaN           NaN
# 2011-01-03  0.196364      0.363478      0.344167           NaN           NaN
# 2011-01-04  0.200000      0.196364      0.363478      0.344167           NaN
# 2011-01-05  0.226957      0.200000      0.196364      0.363478      0.344167
# 2011-01-06  0.204348      0.226957      0.200000      0.196364      0.363478
# 2011-01-07  0.196522      0.204348      0.226957      0.200000      0.196364
# 2011-01-08  0.165000      0.196522      0.204348      0.226957      0.200000
# 2011-01-09  0.138333      0.165000      0.196522      0.204348      0.226957
# 2011-01-10  0.150833      0.138333      0.165000      0.196522      0.204348
#
#             temp_shift_5
# dteday
# 2011-01-01           NaN
# 2011-01-02           NaN
# 2011-01-03           NaN
# 2011-01-04           NaN
# 2011-01-05           NaN
# 2011-01-06      0.344167
# 2011-01-07      0.363478
# 2011-01-08      0.196364
# 2011-01-09      0.200000
# 2011-01-10      0.226957

# %%
feature_tr_df, feature_ts_df, target_tr, target_ts = time_series_train_test_split(temp_df, 'temp')

# %%
feature_tr_df.shape, feature_ts_df.shape
# Out:
# ((511, 5), (215, 5))

# %%
from sklearn.linear_model import Ridge

ridge = Ridge()

ridge.fit(feature_tr_df, target_tr)
ridge.score(feature_tr_df, target_tr), ridge.score(feature_ts_df, target_ts)
# Out:
# (0.88894462324969892, 0.92065411167989675)

# %%
predictions_df['temp_shift_5_model'] = pd.concat([pd.Series(ridge.predict(feature_tr_df), index=feature_tr_df.index),
                                                  pd.Series(ridge.predict(feature_ts_df), index=feature_ts_df.index)])

# %%
predictions_df.plot(figsize=(20,3))

# %%
predictions_df['2012-01'].plot(figsize=(20,3))

# %%
predictions_df['06/2012'].plot(figsize=(20,3))

# %% [markdown]
# ##### You may need a lag value from last week, last month, and last year. This comes down to the specific domain.

# %% [markdown]
# ### Rolling Window Statistics

# %%
width = 3
window = temp_df.temp_shift_1.rolling(window=width)

# %%
temp_df['min'] = window.min()
temp_df['mean'] = window.mean()
temp_df['max'] = window.max()

# %%
temp_df.columns
# Out:
# Index(['temp', 'temp_shift_1', 'temp_shift_2', 'temp_shift_3', 'temp_shift_4',
#        'temp_shift_5', 'min', 'mean', 'max'],
#       dtype='object')

# %%
temp_df[['temp', 'temp_shift_1', 'min', 'mean', 'max']].head(15)
# Out:
#                 temp  temp_shift_1       min      mean       max
# dteday
# 2011-01-01  0.344167           NaN       NaN       NaN       NaN
# 2011-01-02  0.363478      0.344167       NaN       NaN       NaN
# 2011-01-03  0.196364      0.363478       NaN       NaN       NaN
# 2011-01-04  0.200000      0.196364  0.196364  0.301336  0.363478
# 2011-01-05  0.226957      0.200000  0.196364  0.253281  0.363478
# 2011-01-06  0.204348      0.226957  0.196364  0.207774  0.226957
# 2011-01-07  0.196522      0.204348  0.200000  0.210435  0.226957
# 2011-01-08  0.165000      0.196522  0.196522  0.209276  0.226957
# 2011-01-09  0.138333      0.165000  0.165000  0.188623  0.204348
# 2011-01-10  0.150833      0.138333  0.138333  0.166618  0.196522
# 2011-01-11  0.169091      0.150833  0.138333  0.151389  0.165000
# 2011-01-12  0.172727      0.169091  0.138333  0.152752  0.169091
# 2011-01-13  0.165000      0.172727  0.150833  0.164217  0.172727
# 2011-01-14  0.160870      0.165000  0.165000  0.168939  0.172727
# 2011-01-15  0.233333      0.160870  0.160870  0.166199  0.172727

# %%
temp_df.head(15)
# Out:
#                 temp  temp_shift_1  temp_shift_2  temp_shift_3  temp_shift_4  \
# dteday
# 2011-01-01  0.344167           NaN           NaN           NaN           NaN
# 2011-01-02  0.363478      0.344167           NaN           NaN           NaN
# 2011-01-03  0.196364      0.363478      0.344167           NaN           NaN
# 2011-01-04  0.200000      0.196364      0.363478      0.344167           NaN
# 2011-01-05  0.226957      0.200000      0.196364      0.363478      0.344167
# 2011-01-06  0.204348      0.226957      0.200000      0.196364      0.363478
# 2011-01-07  0.196522      0.204348      0.226957      0.200000      0.196364
# 2011-01-08  0.165000      0.196522      0.204348      0.226957      0.200000
# 2011-01-09  0.138333      0.165000      0.196522      0.204348      0.226957
# 2011-01-10  0.150833      0.138333      0.165000      0.196522      0.204348
# 2011-01-11  0.169091      0.150833      0.138333      0.165000      0.196522
# 2011-01-12  0.172727      0.169091      0.150833      0.138333      0.165000
# 2011-01-13  0.165000      0.172727      0.169091      0.150833      0.138333
# 2011-01-14  0.160870      0.165000      0.172727      0.169091      0.150833
# 2011-01-15  0.233333      0.160870      0.165000      0.172727      0.169091
#
#             temp_shift_5       min      mean       max
# dteday
# 2011-01-01           NaN       NaN       NaN       NaN
# 2011-01-02           NaN       NaN       NaN       NaN
# 2011-01-03           NaN       NaN       NaN       NaN
# 2011-01-04           NaN  0.196364  0.301336  0.363478
# 2011-01-05           NaN  0.196364  0.253281  0.363478
# 2011-01-06      0.344167  0.196364  0.207774  0.226957
# 2011-01-07      0.363478  0.200000  0.210435  0.226957
# 2011-01-08      0.196364  0.196522  0.209276  0.226957
# 2011-01-09      0.200000  0.165000  0.188623  0.204348
# 2011-01-10      0.226957  0.138333  0.166618  0.196522
# 2011-01-11      0.204348  0.138333  0.151389  0.165000
# 2011-01-12      0.196522  0.138333  0.152752  0.169091
# 2011-01-13      0.165000  0.150833  0.164217  0.172727
# 2011-01-14      0.138333  0.165000  0.168939  0.172727
# 2011-01-15      0.150833  0.160870  0.166199  0.172727

# %%
feature_tr_df, feature_ts_df, target_tr, target_ts = time_series_train_test_split(temp_df, 'temp')

# %%
feature_tr_df.shape, feature_ts_df.shape
# Out:
# ((511, 1), (217, 1))

# %%
from sklearn.linear_model import Ridge

ridge = Ridge()

ridge.fit(feature_tr_df, target_tr)
ridge.score(feature_tr_df, target_tr), ridge.score(feature_ts_df, target_ts)
# Out:
# (0.8898422289369925, 0.92132605840775661)

# %%
predictions_df['temp_rolling_window'] = pd.concat([pd.Series(ridge.predict(feature_tr_df), index=feature_tr_df.index),
                                                   pd.Series(ridge.predict(feature_ts_df), index=feature_ts_df.index)])

# %%
predictions_df.plot(figsize=(20,3))

# %%
predictions_df['2012-01'].plot(figsize=(20,3))

# %%
predictions_df['06/2012'].plot(figsize=(20,3))

# %% [markdown]
# #### Just the Moving Average

# %%
feature_tr_df, feature_ts_df, target_tr, target_ts = time_series_train_test_split(temp_df[['mean','temp']], 'temp')

# %%
feature_tr_df.shape, feature_ts_df.shape
# Out:
# ((511, 1), (217, 1))

# %%
from sklearn.linear_model import Ridge

ridge = Ridge()

ridge.fit(feature_tr_df, target_tr)
ridge.score(feature_tr_df, target_tr), ridge.score(feature_ts_df, target_ts)
# Out:
# (0.8285389247328111, 0.87729644612982038)

# %%
predictions_df['temp_ma'] = pd.concat([pd.Series(ridge.predict(feature_tr_df), index=feature_tr_df.index),
                                                   pd.Series(ridge.predict(feature_ts_df), index=feature_ts_df.index)])

# %%
predictions_df.plot(figsize=(20,3))

# %%
predictions_df['2012-01'].plot(figsize=(20,3))

# %%
predictions_df['06/2012'].plot(figsize=(20,3))
